# %%
#1
import pandas as pd
df = pd.read_csv('acc_players-2324F.csv', skiprows=1)
df.head()
# Out:
#    Rk         Player Class Pos          School   G   MP  TRB  AST  STL  ...  \
# 0   1   Amaree Abram    SO   G    Georgia Tech  10  108   17   11    1  ...
# 1   2   Sola Adebisi    FR   F   Florida State   7    9    1    1    0  ...
# 2   3  Prince Aligbe    SO   F  Boston College  35  651  119   21   15  ...
# 3   4     Abe Atiyeh    SR   G  Boston College   4    6    0    0    0  ...
# 4   5    Zack Austin    JR   F      Pittsburgh  33  746  137   29   32  ...
#
#    TOV  PF  PTS    FG%    2P%    3P%    FT%   PER   WS  BPM
# 0    9  10   34  0.262  0.318  0.200  0.615   4.1 -0.1 -6.4
# 1    1   1    2  0.500  0.500    NaN    NaN   3.5  0.0 -6.7
# 2   30  51  164  0.435  0.522  0.147  0.620   9.4  0.9 -1.3
# 3    1   0    3  0.333  0.000  1.000    NaN   1.1  0.0 -8.2
# 4   13  35  216  0.417  0.563  0.295  0.737  18.0  2.9  7.9
#
# [5 rows x 21 columns]

# %%
#2
total_points = df['PTS'].sum()
print("Total points scored by all players:", total_points)

most_minutes_player = df.loc[df['MP'].idxmax()]
print("Player with the most minutes played:", most_minutes_player['Player'], "-", most_minutes_player['MP'], "minutes")

top_5_rebounds = df[['Player', 'TRB']].sort_values(by='TRB', ascending=False).head(5)
print("Top 5 players by total rebounds:")
print(top_5_rebounds)
# Out:
# Total points scored by all players: 38411
# Player with the most minutes played: Casey Morsell - 1333 minutes
# Top 5 players by total rebounds:
#               Player  TRB
# 5      Armando Bacot  380
# 178  Ian Schieffelin  340
# 90   Harrison Ingram  327
# 44    Mohamed Diarra  311
# 149    Norchad Omier  309

# %%
#3
df_filtered = df[df['MP'] > 500]

highest_assists_player = df_filtered.loc[df_filtered['AST'].idxmax()]
print("Player with the highest total assists:", highest_assists_player['Player'], "-", highest_assists_player['AST'], "assists")

top_3_assist_leaders = df_filtered[['Player', 'AST']].sort_values(by='AST', ascending=False).head(3)
print("Top 3 Assist Leaders:")
print(top_3_assist_leaders)

top_3_shot_blockers = df_filtered[['Player', 'BLK']].sort_values(by='BLK', ascending=False).head(3)
print("Top 3 Shot Blockers:")
print(top_3_shot_blockers)
# Out:
# Player with the highest total assists: Reece Beekman - 212 assists
# Top 3 Assist Leaders:
#              Player  AST
# 7     Reece Beekman  212
# 215  Jaeden Zackery  152
# 21    Elliot Cadeau  150
# Top 3 Shot Blockers:
#             Player  BLK
# 51       Ryan Dunn   77
# 157   Quinten Post   61
# 5    Armando Bacot   56

# %%
#4
school_points = df.groupby('School')['PTS'].sum()
print("Total points scored by each school:")
print(school_points)

school_assists = df.groupby('School')['AST'].sum()
print("Total assists by each school:")
print(school_assists)

top_3_schools_points = school_points.sort_values(ascending=False).head(3)
print("Top 3 schools by total points:")
print(top_3_schools_points)
# Out:
# Total points scored by each school:
# School
# Boston College    2667
# Clemson           2785
# Duke              2830
# Florida State     2526
# Georgia Tech      2272
# Louisville        2304
# Miami (FL)        2424
# NC State          3101
# North Carolina    3032
# Notre Dame        2113
# Pittsburgh        2495
# Syracuse          2442
# Virginia          2140
# Virginia Tech     2547
# Wake Forest       2733
# Name: PTS, dtype: int64
# Total assists by each school:
# School
# Boston College    509
# Clemson           533
# Duke              551
# Florida State     406
# Georgia Tech      425
# Louisville        356
# Miami (FL)        454
# NC State          536
# North Carolina    536
# Notre Dame        335
# Pittsburgh        452
# Syracuse          442
# Virginia          509
# Virginia Tech     514
# Wake Forest       429
# Name: AST, dtype: int64
# Top 3 schools by total points:
# School
# NC State          3101
# North Carolina    3032
# Duke              2830
# ...

# %%
#5
import matplotlib.pyplot as plt
top_5_players_points = df[['Player', 'PTS']].sort_values(by='PTS', ascending=False).head(5)
plt.bar(top_5_players_points['Player'], top_5_players_points['PTS'])
plt.xlabel('Player')
plt.ylabel('Points')
plt.title('Top 5 Players by Total Points')
plt.show()


plt.scatter(df['FG%'], df['WS'])
plt.xlabel('Field Goal Percentage (FG%)')
plt.ylabel('Win Shares (WS)')
plt.title('Correlation between FG% and WS')
plt.show()

correlation = df['FG%'].corr(df['WS'])
print("Correlation between FG% and WS:", correlation)
# Out:
# Correlation between FG% and WS: 0.42106638941997815

# %%
#reflection
#In this assignment, I learned how to efficiently read and work with CSV files using pandas DataFrames 
#while applying data science principles to analyze the date. 
#This is necessary for applying the correct analysis techniques and understanding the data I am given. 
#Loading the data and using functions like .head() and .describe() provided an initial explanation, 
#which helped in understanding the dataset’s shape and key statistics.

# %%
#reflection
#The most challenging aspect of this assignment was understanding how to apply different functions 
#for specific operations. I overcame these challenges by reading the pandas documentation 
#and experimenting with different approaches, ultimately gaining confidence in using pandas for 
#more complex data tasks.

# %%
#reflection
#The insights gained from analyzing ACC basketball statistics could be applied to other real-world datasets, 
#such as business, healthcare, or economics. 
#Using data analysis techniques on large datasets allows for valuable insights and decision-making. 
#This experience prepares me for tackling more advanced challenges in data science, where similar methodologies can be used
